# %% [markdown]
# # Chirp

# %%
import numpy as np
from scipy import fft

# %% [markdown]
# ## Load the data

# %%
chirp = ...
acqs = ...

# %% [markdown]
# To analyze a chirp we will need two the chirp current that we injected into the cell. If you know how your recording program created the chirp then you can just recreate it. Otherwise if you used something like an ATF file you will need to load the file into python.
# The reason we need the actual chirp stimulus is that we have to remove the frequency content of the chirp from the cell's voltage. The cell voltage will oscillate at the frequency the chirp is at no matter what but we want to see how the membrane reacts.

# %% [markdown]
# ## Take the FFT of your recording and chirp

# %%
fastest = fft.next_fast_len(chirp.size)
c_fft = fft.rfft(chirp, n=fastest)
a_fft = fft.rfft(acqs[1].acquisition[:chirp.size], n=fastest)

# %% [markdown]
# ## Create the impeadance

# %%
z = a_fft/c_fft
impeadance = np.abs(z)
